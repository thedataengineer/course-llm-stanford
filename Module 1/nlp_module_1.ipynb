# %%
# !pip install -U spacy
# !pip install -U gensim

# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: spacy in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (3.8.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: numpy>=1.19.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: jinja2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (58.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (24.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: language-data>=1.2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: click>=8.0.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: wrapt in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from jinja2->spacy) (3.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/thekarteek/code/course/stanford/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: gensim in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (4.3.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from gensim) (7.1.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: wrapt in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/thekarteek/code/course/stanford/bin/python3 -m pip install --upgrade pip' command.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/thekarteek/code/course/stanford/bin/python3 -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !ls
# Out:
# Module_1_Foundation_LLM_Maven_v2_module_1.ipynb
# Module_1_Foundation_LLMs-Maven-v2.pptx.pdf
# nlp_module_1.ipynb

# %% [markdown]
# #Basic NLP

# %%
# Data Cleaning

import re

#sample review from the IMDB dataset.
review = "<b>A touching movie!!</b> It is full of emotions and wonderful acting.<br> I could have sat through it a second time."

cleaned_review = re.sub(re.compile('<.*?>'), '', review) #removing HTML tags
cleaned_review = re.sub('[^A-Za-z0-9]+', ' ', cleaned_review) #taking only words

print(cleaned_review)
# Out:
# A touching movie It is full of emotions and wonderful acting I could have sat through it a second time

# %%
#Lowercase
cleaned_review = cleaned_review.lower()
print(cleaned_review)
# Out:
# a touching movie it is full of emotions and wonderful acting i could have sat through it a second time

# %%
# Tokenization
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

tokens = nltk.word_tokenize(cleaned_review)

print(cleaned_review)
print(tokens)
# Out:
# a touching movie it is full of emotions and wonderful acting i could have sat through it a second time
# ['a', 'touching', 'movie', 'it', 'is', 'full', 'of', 'emotions', 'and', 'wonderful', 'acting', 'i', 'could', 'have', 'sat', 'through', 'it', 'a', 'second', 'time']
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/thekarteek/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
cleaned_review
# Out:
# 'a touching movie it is full of emotions and wonderful acting i could have sat through it a second time '

# %%
tokens
# Out:
# ['a',
#  'touching',
#  'movie',
#  'it',
#  'is',
#  'full',
#  'of',
#  'emotions',
#  'and',
#  'wonderful',
#  'acting',
#  'i',
#  'could',
#  'have',
#  'sat',
#  'through',
#  'it',
#  'a',
#  'second',
#  'time']

# %%
# Stop words removal

nltk.download('stopwords')

from nltk.corpus import stopwords

stop_words = stopwords.words('english')

filtered_review = [word for word in tokens if word not in stop_words] # removing stop words

print(filtered_review)
# Out:
# ['touching', 'movie', 'full', 'emotions', 'wonderful', 'acting', 'could', 'sat', 'second', 'time']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/thekarteek/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words.append('Hamza')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer


lemmatizer = WordNetLemmatizer()

lemm_review = [lemmatizer.lemmatize(word) for word in filtered_review]

print(lemm_review)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/thekarteek/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/thekarteek/nltk_data...
# ['touching', 'movie', 'full', 'emotion', 'wonderful', 'acting', 'could', 'sat', 'second', 'time']

# %%
from nltk import word_tokenize, pos_tag
nltk.download('averaged_perceptron_tagger')
text = "I am learning Natural Language Processing on Analytics Vidhya"
nltk.download('averaged_perceptron_tagger_eng')

tokens = word_tokenize(text)
print (pos_tag(tokens))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/thekarteek/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/thekarteek/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('I', 'PRP'), ('am', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP'), ('on', 'IN'), ('Analytics', 'NNP'), ('Vidhya', 'NNP')]

# %% [markdown]
# # Spacy

# %%
import os
import spacy
nlp = spacy.load("en_core_web_sm")
from spacy import displacy

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
print(nlp.pipeline)
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x31cea2e80>), ('tagger', <spacy.pipeline.tagger.Tagger object at 0x31d1130a0>), ('parser', <spacy.pipeline.dep_parser.DependencyParser object at 0x31b3117b0>), ('attribute_ruler', <spacy.pipeline.attributeruler.AttributeRuler object at 0x319600c40>), ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer object at 0x3195ad3c0>), ('ner', <spacy.pipeline.ner.EntityRecognizer object at 0x31b311dd0>)]

# %%
text = """Looking for a hotel in New York near Times Square with free breakfast and cheaper
than $100 for 2nd June which is really kids friendly and has a swimming pool and I want to stay there for 8 days"""
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(doc, jupyter = True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Looking for a hotel in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  near
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  with free breakfast and cheaper<br>than $100 for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2nd June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  which is really kids friendly and has a swimming pool and I want to stay there for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
text = """Close to the Effiel Tower and is very high end with great shopping nearby"""
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(doc, jupyter = True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Close to
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Effiel Tower
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  and is very high end with great shopping nearby</div></span>

# %%
text = "I want to stay in a European city that filmed Game of Thrones and has very cheap booze and art galleries for 4 days"

# %%
#text = """My very photogenic mother died in a freak accident (picnic, lightning) when I was three, and, save for a pocket of warmth in the darkest past, nothing of her subsists within the hollows and dells of memory, over which, if you can still stand my style (I am writing under observation), the sun of my infancy had set: surely, you all know those redolent remnants of day suspended, with the midges, about some hedge in bloom or suddenly entered and traversed by the rambler, at the bottom of a hill, in the summer dusk; a furry warmth, golden midges"""
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(doc, jupyter = True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I want to stay in a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  city that filmed Game of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thrones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and has very cheap booze and art galleries for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
spacy.explain("NORP")
# Out:
# 'Nationalities or religious or political groups'

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain("FAC")
# Out:
# 'Buildings, airports, highways, bridges, etc.'

# %%
from spacy import displacy
text = ("Natural Language Processing provides computers the capability of understanding text")
text_doc_object = nlp(text)
displacy.render(text_doc_object, style='dep',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="46e0a1f74a794b4e9e44c4ea09dcd956-0" class="displacy" width="1800" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">provides</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">computers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">capability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">understanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-5" stroke-width="2px" d="M595,177.0 C595,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-6" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,179.0 L1278.0,167.0 1262.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-7" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,179.0 L1453.0,167.0 1437.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-8" stroke-width="2px" d="M1470,177.0 C1470,89.5 1620.0,89.5 1620.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-46e0a1f74a794b4e9e44c4ea09dcd956-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displac

# %%
spacy.explain("DET")
# Out:
# 'determiner'

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 4.7 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.56.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 34.5 MB/s eta 0:00:01�███████████████████▎     | 2.3 MB 34.5 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp39-cp39-macosx_11_0_arm64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 26.2 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.9 MB/s  eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 66.4 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 52.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.23 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/thekarteek/code/course/stanford/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.56.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.1.0 pyparsing-3.2.1
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/thekarteek/code/course/stanford/bin/python3 -m pip install --upgrade pip' command.

# %%
text = ('''Physics is a fundamental branch of science that seeks to understand the fundamental principles that govern the behavior of the universe. It encompasses a broad range of phenomena, from the smallest subatomic particles to the largest structures in the universe, such as galaxies and black holes.

The study of physics is based on a few fundamental concepts, such as space, time, mass, energy, and force. These concepts provide a framework for understanding the behavior of physical systems and the interactions between them.

One of the key achievements of physics is the development of a set of mathematical equations that describe the behavior of physical systems. These equations allow physicists to make predictions about the behavior of a system and test those predictions through experimentation.

One of the most important concepts in physics is the theory of relativity, which was developed by Albert Einstein in the early 20th century. The theory of relativity explains how the laws of physics are the same for all observers in all inertial frames of reference, regardless of their relative motion. It also explains the nature of gravity as a curvature of spacetime caused by the presence of mass and energy.

Another important area of physics is quantum mechanics, which deals with the behavior of particles on a very small scale, such as atoms and subatomic particles. Quantum mechanics is based on the idea that particles can exist in multiple states at the same time, and that the act of measurement can cause a particle to collapse into a single state. This leads to some strange and counterintuitive phenomena, such as entanglement, where the properties of one particle can affect the properties of another particle instantaneously over vast distances.

Physics has many practical applications in areas such as engineering, technology, and medicine. For example, the principles of physics are used in the design of bridges, buildings, and other structures, as well as in the development of new technologies such as semiconductors and lasers. In medicine, physics is used in the development of imaging technologies such as X-rays, MRI, and CT scans, as well as in the development of radiation therapy for cancer treatment.

In conclusion, physics is a fundamental branch of science that seeks to understand the behavior of the universe through the study of fundamental concepts such as space, time, mass, energy, and force. Its achievements have led to a deeper understanding of the universe and have practical applications that benefit society in many ways.''')
text_doc_object = nlp(text)
from collections import Counter
words = [token.text for token in text_doc_object if not token.is_punct and not  token.is_stop and not token.is_space]
word_freq = Counter(words)
common_words = word_freq.most_common(30)
first=[]
second=[]
for i in common_words:
    first.append(i[0])
    second.append(i[1])
import matplotlib.pyplot as plt
plt.bar(first, second,  color='orange')
plt.xticks(range(len(first)), first, rotation='vertical')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
text = ('''Physics is a fundamental branch of science that seeks to understand the fundamental principles that govern the behavior of the universe. It encompasses a broad range of phenomena, from the smallest subatomic particles to the largest structures in the universe, such as galaxies and black holes.

The study of physics is based on a few fundamental concepts, such as space, time, mass, energy, and force. These concepts provide a framework for understanding the behavior of physical systems and the interactions between them.

One of the key achievements of physics is the development of a set of mathematical equations that describe the behavior of physical systems. These equations allow physicists to make predictions about the behavior of a system and test those predictions through experimentation.

One of the most important concepts in physics is the theory of relativity, which was developed by Albert Einstein in the early 20th century. The theory of relativity explains how the laws of physics are the same for all observers in all inertial frames of reference, regardless of their relative motion. It also explains the nature of gravity as a curvature of spacetime caused by the presence of mass and energy.

Another important area of physics is quantum mechanics, which deals with the behavior of particles on a very small scale, such as atoms and subatomic particles. Quantum mechanics is based on the idea that particles can exist in multiple states at the same time, and that the act of measurement can cause a particle to collapse into a single state. This leads to some strange and counterintuitive phenomena, such as entanglement, where the properties of one particle can affect the properties of another particle instantaneously over vast distances.

Physics has many practical applications in areas such as engineering, technology, and medicine. For example, the principles of physics are used in the design of bridges, buildings, and other structures, as well as in the development of new technologies such as semiconductors and lasers. In medicine, physics is used in the development of imaging technologies such as X-rays, MRI, and CT scans, as well as in the development of radiation therapy for cancer treatment.

In conclusion, physics is a fundamental branch of science that seeks to understand the behavior of the universe through the study of fundamental concepts such as space, time, mass, energy, and force. Its achievements have led to a deeper understanding of the universe and have practical applications that benefit society in many ways.''')
text_doc_object = nlp(text)
from collections import Counter
words = [token.text for token in text_doc_object if not token.is_punct and not  token.is_stop and not token.is_space]
word_freq = Counter(words)
common_words = word_freq.most_common(30)
first=[]
second=[]
for i in common_words:
    first.append(i[0])
    second.append(i[1])
import matplotlib.pyplot as plt
plt.bar(first, second,  color='orange')
plt.xticks(range(len(first)), first, rotation='vertical')
plt.show()

# %%
text_doc_object = nlp(text.lower())
from collections import Counter
words = [token.text for token in text_doc_object if not token.is_punct and not  token.is_stop and not token.is_space]
word_freq = Counter(words)
common_words = word_freq.most_common(30)
first=[]
second=[]
for i in common_words:
    first.append(i[0])
    second.append(i[1])
import matplotlib.pyplot as plt
plt.bar(first, second,  color='orange')
plt.xticks(range(len(first)), first, rotation='vertical')
plt.show()

# %%
# Create the nlp object
nlp = spacy.load("en_core_web_sm")
from spacy.language import Language

# Define a custom component
@Language.component("custom_component")
def custom_component_function(doc):
    # Print the doc's length
    print("Your Doc length:", len(doc))
    # Return the doc object
    return doc

# Add the component first in the pipeline
nlp.add_pipe("custom_component", first=True)

# Print the pipeline component names
print("Pipeline:", nlp.pipe_names)
# Out:
# Pipeline: ['custom_component', 'tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
text = ("Natural Language Processing provides computers the capability of understanding text")
text_doc_object = nlp(text)
# Out:
# Your Doc length: 10

# %%
stopwords=list(STOP_WORDS)
from string import punctuation
punctuation=punctuation+ '\n'

# %%
# Load a larger pipeline with vectors
# !python -m spacy download en_core_web_md
nlp = spacy.load("en_core_web_md")




# Compare two documents
doc1 = nlp("I like fast food")
doc2 = nlp("I like pizza")
print(doc1.similarity(doc2))
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      |████████████████████████████████| 33.5 MB 10.1 MB/s eta 0:00:01
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/thekarteek/code/course/stanford/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# 0.8382381514100752

# %%
nlp = spacy.load("en_core_web_md")
# Compare two documents
doc1 = nlp("I like fast food")
doc2 = nlp("I like pizza")
print(doc1.similarity(doc2))
# Out:
# 0.8382381514100752
